# %% [markdown]
# <a href="https://colab.research.google.com/github/JT-3710A/Neural-Network--Workshop/blob/main/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2#this is a open cv library used in image processing
import torch

# %%
image=cv2.imread('/content/sample_data/PNG_transparency_demonstration_1.png')

# %%
image.shape

# %%
# cv2.imshow(image)#it is done in notebook but in google colab we do differently
from google.colab.patches import cv2_imshow
cv2_imshow(image)
#OPEN CV DEFULT SET TO RGB

# %%
height=400
width=500
resized_image=cv2.resize(image,(width,height))
cv2_imshow(resized_image)

# %%
resized_image.shape

# %%
cropped_image=image[150:400,200:600]

# %%
cv2_imshow(cropped_image)

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
cropped = image[180:440, 250:580]

# %%
cv2_imshow(cropped)

# %%
new_image=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)

# %%
cv2_imshow(new_image)

# %%
grey_image=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

# %%
from google.colab.patches import cv2_imshow

# %%
grey_image.shape

# %%
cv2_imshow(grey_image)

# %%
rgb_image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
rgb_image

# %%
blur_image=cv2.imread('/content/sample_data/PNG_transparency_demonstration_1.png')

# %%
cv2_imshow(blur_image)

# %%
new_image=cv2.blur(blur_image,(25,25))#used to blur the images

# %%
cv2_imshow(new_image)

# %%
img=cv2.imread('/content/sample_data/0_aycSUVVDcHMnuFgc.png')

# %%
img

# %%
new_img=cv2.medianBlur(img,5)

# %%
new_img

# %%
edge_img=cv2.Canny(image=img,threshold1=50,threshold2=200)
cv2_imshow(edge_img)

# %%
edge_img

# %%
edge1_img=cv2.Canny(image=blur_image,threshold1=50,threshold2=200)#this is how edge is deected in images using this code
cv2_imshow(edge1_img)
